# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sb
from sklearn import datasets, linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py

# %%
df= pd.read_excel("Kmeans5.xlsx")

# %%
df.head(5)
# Out:
#     ID  coop empty h  after CC  after CD  after DC  after DD  COUNT  k5 kname  \
# 0  332      1.000000  0.428571      0.80  0.333333  0.666667     25   4    AC
# 1  334      1.000000  1.000000      0.00  1.000000  0.000000     25   2   TFT
# 2  328      0.714286  0.800000      0.75  0.333333  0.000000     25   0  GRIM
# 3  329      0.142857  1.000000      0.00  1.000000  0.000000     25   3  STFT
# 4  327      0.000000  0.000000      0.00  0.000000  0.000000     25   1    AD
#
#    HCDDC  HCCDD  Empty history  After CC  After CD  After DC  After DD
# 0      3      3       1.000000  0.428571      0.80  0.333333  0.666667
# 1      3      3       1.000000  1.000000      0.00  1.000000  0.000000
# 2      3      3       0.714286  0.800000      0.75  0.333333  0.000000
# 3      3      3       0.142857  1.000000      0.00  1.000000  0.000000
# 4      2      2       0.000000  0.000000      0.00  0.000000  0.000000

# %%
df2 = df[['coop empty h','after CC','after CD','after DC','after DD']]
df3 = df[['coop empty h','after CC','after CD','after DC','after DD','kname']]

df22 = df[['Empty history','After CC','After CD','After DC','After DD']]
df33 = df[['Empty history','After CC','After CD','After DC','After DD','kname']]

# %%
sns.set(font_scale = 1.4)
sns.set_style("white")
palleta = ['#3EA055','#B2C248','#FFA500','r','#800517']
sb.pairplot(df33,hue='kname',palette=palleta,corner=False, height=2.5, aspect=1)
plt.savefig('save_as_a_png.png')

# %%
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

df1 = df[df['k5']==1]
x1 = df1['coop empty h']
y1 = df1['after CC']
z1 = df1['after DD']

df2 = df[df['k5']==2]
x2 = df2['coop empty h']
y2 = df2['after CC']
z2 = df2['after DD']

df3 = df[df['k5']==3]
x3 = df3['coop empty h']
y3 = df3['after CC']
z3 = df3['after DD']

df4 = df[df['k5']==4]
x4 = df4['coop empty h']
y4 = df4['after CC']
z4 = df4['after DD']

df0 = df[df['k5']==0]
x0 = df0['coop empty h']
y0 = df0['after CC']
z0 = df0['after DD']



fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection='3d')


ax.scatter3D(x1, y1, z1, edgecolor = 'snow', c = '#800517',s=150)
ax.scatter3D(x3, y3, z3, edgecolor = 'snow',c = 'r',s=150)
ax.scatter3D(x0, y0, z0, edgecolor = 'snow',c = '#FFA500',s=150)
ax.scatter3D(x2, y2, z2, edgecolor = 'snow',c = '#B2C248',s=150)
ax.scatter3D(x4, y4, z4, edgecolor = 'snow',c = '#3EA055',s =150)

ax.scatter3D(0.07, 0.18, 0.02, edgecolor = 'k',c = '#800517',s=2500)
ax.scatter3D(0.74, 0.96, 0.07, edgecolor = 'k',c = '#FFA500',s=2500)
ax.scatter3D(0.85, 0.98, 0.06, edgecolor = 'k',c = '#B2C248',s=2500)
ax.scatter3D(0.22, 0.95, 0.07, edgecolor = 'k',c = 'r',s=2500)
ax.scatter3D(0.80, 0.94, 0.61, edgecolor = 'k',c = '#3EA055',s=2500)

ax.set_xlabel('empty history', fontsize=22, rotation=150)
ax.set_ylabel('After CC', fontsize=22, rotation=150)
ax.set_zlabel('After DD', fontsize=22, rotation=150)
plt.legend(['AD','STFT','GRIM','TFT','AC'])
plt.title("Classification- Prob. to Coop")

plt.show()

# %%
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

df1 = df[df['k5']==1]
x1 = df1['coop empty h']
y1 = df1['after CD']
z1 = df1['after DC']

df2 = df[df['k5']==2]
x2 = df2['coop empty h']
y2 = df2['after CD']
z2 = df2['after DC']

df3 = df[df['k5']==3]
x3 = df3['coop empty h']
y3 = df3['after CD']
z3 = df3['after DC']

df4 = df[df['k5']==4]
x4 = df4['coop empty h']
y4 = df4['after CD']
z4 = df4['after DC']

df0 = df[df['k5']==0]
x0 = df0['coop empty h']
y0 = df0['after CD']
z0 = df0['after DC']



fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection='3d')



ax.scatter3D(x1, y1, z1, edgecolor = 'snow', c = '#800517',s=150)
ax.scatter3D(x3, y3, z3, edgecolor = 'snow',c = 'r',s=150)
ax.scatter3D(x0, y0, z0, edgecolor = 'snow',c = '#FFA500',s=100)
ax.scatter3D(x2, y2, z2, edgecolor = 'snow',c = '#B2C248',s=150)
    ax.scatter3D(x4, y4, z4, edgecolor = 'snow',c = '#3EA055',s =150)


ax.scatter3D(0.07, 0.18, 0.08, edgecolor = 'k',c = '#800517',s=2500)
ax.scatter3D(0.74, 0.26, 0.16, edgecolor = 'k',c = '#FFA500',s=2500)
ax.scatter3D(0.85, 0.29, 0.75, edgecolor = 'k',c = '#B2C248',s=2500)
ax.scatter3D(0.22, 0.39, 0.32, edgecolor = 'k',c = 'r',s=2500)
ax.scatter3D(0.80, 0.61, 0.56, edgecolor = 'k',c = '#3EA055',s=2500)

ax.set_xlabel('empty history', fontsize=22, rotation=150)
ax.set_ylabel('After CD', fontsize=22, rotation=150)
ax.set_zlabel('After DC', fontsize=22, rotation=150)

#plt.title("Classification- Prob. to Coop")

plt.show()
# Out:
#   Input In [7]
#     ax.scatter3D(x4, y4, z4, edgecolor = 'snow',c = '#3EA055',s =150)
#     ^
# IndentationError: unexpected indent

# %%
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

df33 = df[df['HCDDC']==3]
x33 = df33['coop empty h']
y33 = df33['after CD']
z33 = df33['after DC']

df22 = df[df['HCDDC']==2]
x22 = df22['coop empty h']
y22 = df22['after CD']
z22 = df22['after DC']

df11 = df[df['HCDDC']==1]
x11 = df11['coop empty h']
y11 = df11['after CD']
z11 = df11['after DC']




fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection='3d')



ax.scatter3D(x33, y33, z33, edgecolor = 'snow', c = '#69B7FC',s=170)
ax.scatter3D(x22, y22, z22, edgecolor = 'snow',c = '#6C3483',s=450,marker = "^") #0029C0
ax.scatter3D(x11, y11, z11, edgecolor = 'snow',c = '#CB4335',s=1000 ,marker = "X")#02066C



#ax.set_xlabel('empty history', fontsize=22, rotation=150)
#ax.set_ylabel('After CD', fontsize=22, rotation=150)
#ax.set_zlabel('After DC', fontsize=22, rotation=150)
#plt.title("Classification- Prob. to Coop")
plt.legend(['All 3 histories exist','2 histories exist','1 histories exist'])

plt.show()

# %%
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

df33 = df[df['HCCDD']==3]
x33 = df33['coop empty h']
y33 = df33['after CC']
z33 = df33['after DD']

df22 = df[df['HCCDD']==2]
x22 = df22['coop empty h']
y22 = df22['after CC']
z22 = df22['after DD']

df11 = df[df['HCCDD']==1]
x11 = df11['coop empty h']
y11 = df11['after CC']
z11 = df11['after DD']




fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection='3d')



ax.scatter3D(x33, y33, z33, edgecolor = 'snow', c = '#69B7FC',s=170)
ax.scatter3D(x22, y22, z22, edgecolor = 'snow',c = '#6C3483',s=450,marker = "^")
ax.scatter3D(x11, y11, z11, edgecolor = 'snow',c = '#CB4335',s=1000 ,marker = "X")



#ax.set_xlabel('empty history', fontsize=22, rotation=150)
#ax.set_ylabel('After CD', fontsize=22, rotation=150)
#ax.set_zlabel('After DC', fontsize=22, rotation=150)
#plt.title("Classification- Prob. to Coop")
#plt.legend(['All 3 histories exist','2 histories exist','1 histories exist'])

plt.show()
